# %% [markdown]
# ## Exercícios

# %% [markdown]
# __1)__ Desenvolva um código que receba do usuário um número inteiro e calcule o fatorial deste número. A fórmula do fatorial é definida como:
#
# <br>
#
# $$ n! = n * (n - 1) * (n - 2) * ... * 2 * 1$$
#
# <br>
#
# Por exemplo $4!$ é igual a $4*3*2*1 = 24$.

# %% [markdown]
# __1.1)__ Desenvolva o código na versão _while_ (1 ponto)

# %%
num = int(input('Digite um número inteiro: '))
fatorial = 1

if num < 0:
  print('Não existe fatorial de número negativo!')
elif num == 0 or num == 1:
  print(f'O fatorial de {num} é = 1.')
else:
  num_digitado = num
  while (num > 1):
    fatorial = fatorial * num
    num -= 1

  print(f'O fatorial de {num_digitado} é = {fatorial}.')
# Out:
# Digite um número inteiro: 5
# O fatorial de 5 é = 120.

# %% [markdown]
# __1.2)__ Desenvolva o código na versão _for_ (1 ponto)

# %%
num = int(input('Digite um número inteiro: '))
fatorial = 1

if num < 0:
  print('Não existe fatorial de número negativo!')
elif num == 0 or num == 1:
  print(f'O fatorial de {num} é = 1.')
else:
  for i in range(1, num + 1):
    fatorial = fatorial * i

  print(f'O fatorial de {num} é = {fatorial}.')
# Out:
# Digite um número inteiro: 5
# O fatorial de 5 é = 120.

# %% [markdown]
# ##

# %% [markdown]
# __2)__ Desenvolva um código que onde pede para o usuário que digite um número inteiro entre 1 e 200, e o código deve printar todos os __números primos__ entre 2 e o número digitado. Número primo é um que seja divisível apenas por 1 ou ele mesmo. Exemplo de números primos : 2, 3, 5, 7, 11, 13, 17 e assim por diante.

# %% [markdown]
# __2.1)__ Desenvolva o código na versão _while_ (1 ponto)

# %%
numero = int(input('Digite o número inteiro (maior que 2): '))
i = 2

print(f'Os números primos entre 2 e {numero} são: ')
while (i <= numero):
  contador = 1 # verificador de número primo. Inicia em 1, pois todo número é divisível por pelo menos um número, o número 1!
  j = 2
  while (j <= i):  
    if (i % j == 0):
      contador += 1
      if contador > 2:
        break
    j += 1
  if contador == 2:
    print(i)
  i += 1
# Out:
# Digite o número inteiro (entre 2 e 200): 17
# Os números primos entre 2 e 17 são:
# 2
# 3
# 5
# 7
# 11
# 13
# 17

# %% [markdown]
# __2.2)__ Desenvolva o código na versão _for_ (1 ponto)

# %%
numero = int(input('Digite o número inteiro (maior que 2): '))

print(f'Os números primos entre 2 e {numero} são: ')
for i in range(2,numero+1): # for para verificar se o número é primo
  contador = 1
  for j in range(2,i+1):    
    if(i % j == 0):
      contador += 1
  if (contador == 2):
    print(i)
# Out:
# Digite o número inteiro (entre 2 e 200): 17
# Os números primos entre 2 e 17 são:
# 2
# 3
# 5
# 7
# 11
# 13
# 17

# %% [markdown]
# ##

# %% [markdown]
# __3)__ (2 pontos) Bibliotecas ou módulos são arquivos contendo algumas funções e outros componentes de código já prontos para serem reutilizados. A linguagem Python já possui diversos módulos pré-instalados, e podemos utilizá-los através do comando import.
#
# Ao incluir a linha abaixo (preferencialmente no topo do programa) podemos acessar as funções do módulo random, que permitem lidar com números aleatórios:
#
# ```python
# import random
# ```
#
# Tendo importado esse módulo em nosso programa, é possível sortear números aleatórios através da função randint. No exemplo abaixo, um número aleatório entre 1 e 100 é salvo na variável "sorteio":
#
# ```python
# sorteio = random.randint(1, 100)
# ```
#
# Faça um programa que sorteia um número aleatório entre 1 e 100. Ele deve pedir para o usuário adivinhar o número até que ele acerte.
#
# Quando o usuário finalmente acertar, exiba a mensagem "Você venceu!" e pergunte se ele gostaria de jogar novamente. Caso ele digite "sim", sorteie um novo número e torne a pedir que ele adivinhe.
#
# Ideia de como estruturar o código:
#
# ```python
# while jogar_de_novo == 'sim':
#   while tentativas < 10:
#     ...
#     ...
#     ...
#     if chute == sorteio:
#       break
#
#     jogar_de_novo = input('Jogar de novo? ')
# ```

# %%
import random

jogar_novamente = 's'

while (jogar_novamente == 's'):
  sorteio = random.randint(1, 15) #sorteia número aleatório entre 1 e 15
  print(sorteio) #apenas para saber qual número foi sorteado
  chute = 0
  tentativas = 5 # quantidade de tentativas
  while (chute != sorteio):
    chute = int(input(f'Você tem {tentativas} tentativa (s). Chute um número: '))
    if chute == sorteio:
      print('Você ACERTOU o número!')
      print('-----------------------------------------')
      jogar_novamente = input(('Deseja jogar novamente [s/n]? '))
      break
    elif tentativas == 1:
      print('Você ERROU e suas tentativas acabaram!')
      print('-----------------------------------------')
      jogar_novamente = input(('Deseja jogar novamente [s/n]? '))
      break
    else:
      print('Você ERROU! Tente novamente.')
      tentativas -= 1
  if jogar_novamente == 'n':
    print('Programa encerrado!')
    break

# %% [markdown]
# __4)__ Desenvolva um programa que recebe como _input_ do usuário dois números inteiros e o retorno do programa será o __mínimo multiplicador comum__ (MMC). Exemplo, o MMC entre 10 e 12, onde $ 10 = 2 * 5$ e $12 = 2 * 2 * 3$, o MMC vai ser o número oriundo da multiplicação entre $ 2 * 2 * 3 * 5 = 60$

# %% [markdown]
# __4.1)__ Desenvolva o código na versão _while_ (1 ponto)

# %%
num1 = int(input('Digite o primeiro número: '))
num2 = int(input('Digite o segundo número: '))
cond = True
if (num1 > num2):
  mmc = num1
else:
  mmc = num2
while (cond):
  if ((mmc % num1 == 0) and (mmc % num2 == 0)):
    print(f'O MMC entre {num1} e {num2} é = {mmc}.')
    cond = False
  else:
    mmc += 1
# Out:
# Digite o primeiro número: 15
# Digite o segundo número: 78
# O MMC entre 15 e 78 é = 390.

# %% [markdown]
# __4.2)__ Desenvolva o código na versão _for_ (1 ponto)

# %%
num1 = int(input('Digite o primeiro número: '))
num2 = int(input('Digite o segundo número: '))

if (num1 > num2):
  mmc = num1
else:
  mmc = num2
for _ in range(num1*num2):
  if ((mmc % num1 == 0) and (mmc % num2 == 0)):
    print(f'O MMC entre {num1} e {num2} é = {mmc}.')
    break
  else:
    mmc += 1
# Out:
# Digite o primeiro número: 15
# Digite o segundo número: 78
# O MMC entre 15 e 78 é = 390.

# %% [markdown]
# __5)__ (2 pontos) Desenvolva um código onde o usuário irá indicar um número inteiro $n$ e o seu código deve devolver o n-ésimo termo da sequência de Fibonacci. A sequência de Fibonacci é definida com o termo $a_1 = 1$ e $a_2 = 1$ e o termo seguinte é a soma dos dois anteriores, então por exemplo $a_3 = a_1 + a_2 = 2$.

# %%
# Exemplo o usuário colocou o valor 7
# sequencia de fibonacci = 1 1 2 3 5 8 13
# devolver o valor 13 que é o sexto da sequência

# %%
n_termo = int(input('Digite o n-ésimo termo inteiro positivo (> 0) desejado: '))

fibo_numero_anterior = 1      # número respectivamente anterior ao número atual desejado da sequência
fibo_numero_antes_anterior = 1 # número respectivamente anterior AO ANTENTERIOR (ou antes-anterior) do número atual desejado da sequência

if (n_termo == 1):
  print(f'O {n_termo}º termo da sequência de Fibonacci é = 1.')
elif (n_termo == 2):
  print(f'O {n_termo}º termo da sequência de Fibonacci é = 1.')
else:
  contador = 3
  while (contador <= n_termo): # se n_termo = 3, o while vai executar apenas uma vez
    fibo_numero_atual = fibo_numero_anterior + fibo_numero_antes_anterior # define o número atual da sequência como sendo a soma dos dois anteriores (anterior + antes_anterior)
    fibo_numero_antes_anterior = fibo_numero_anterior # redefine e iguala o número antes_anteior ao número anterior da sequência para a próxima iteração do while
    fibo_numero_anterior = fibo_numero_atual # redefine e iguala o número anteior ao número atual da sequência para a próxima iteração do while
    contador += 1
  print(f'O {n_termo}º termo da sequência de Fibonacci é = {fibo_numero_atual}.')
# Out:
# Digite o n-ésimo termo inteiro positivo (> 0) desejado: 19
# O 19º termo da sequência de Fibonacci é = 4181.
